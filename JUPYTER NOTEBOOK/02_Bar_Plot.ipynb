# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
flower=sns.load_dataset("iris")
flower
#draw a line plot
sns.barplot(x="species", y="sepal_width" , data=flower)
plt.show()

# %% [markdown]
# ## if we chane sepal_width into petal_length

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
flower=sns.load_dataset("iris")
flower
#draw a line plot
sns.barplot(x="species", y="petal_length" , data=flower)
plt.show()

# %% [markdown]
# # Boats

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
#draw a line plot
sns.barplot(x="sex", y="alone" ,hue="who", data=kashti)
plt.show()

# %% [markdown]
# ## how we can set a order

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
#draw a line plot
sns.barplot(x="sex", y="alone" ,hue="who", data=kashti, order=(['female','male']))
plt.show()

# %% [markdown]
# ## show data in different collors

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
#draw a line plot
sns.barplot(x="sex", y="alone" ,hue="who", data=kashti, order=['female','male'], color="Orange")
plt.show()

# %% [markdown]
# ## remove confidence interval                   ###errors on the bars

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
#draw a line plot
sns.barplot(x="sex", y="alone" ,hue="who", data=kashti, order=['female','male'], color="Orange", errorbar= None)
plt.show()

# %% [markdown]
# ## use color pallete

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
#draw a line plot
sns.barplot(x="sex", y="alone" ,hue="who", data=kashti, order=['female','male'], color="Orange", errorbar= None,
           palette="pastel")
plt.show()

# %% [markdown]
# ## use estimator

# %%
#import libraries
import seaborn as sns
import numpy
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
#draw a line plot
sns.barplot(x="class", y="fare" ,hue="sex", data=kashti, estimator=mean)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 10
#       8 kashti
#       9 #draw a line plot
# ---> 10 sns.barplot(x="class", y="fare" ,hue="sex", data=kashti, estimator=mean)
#      11 plt.show()
#
# NameError: name 'mean' is not defined

# %% [markdown]
# ## Change the saturation or intensity of data

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
#draw a line plot
sns.barplot(x="sex", y="alone" ,hue="who", data=kashti, order=['female','male'], color="Orange", errorbar= None,
           palette="pastel",saturation=0.4)
plt.show()

# %% [markdown]
# ## make a horizontal graph

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
#draw a line plot
sns.barplot(x="alone", y="sex" ,hue="who", data=kashti, order=['female','male'], color="Orange", errorbar= None,
           palette="pastel",saturation=0.4)
plt.show()

# %%
# Make a different graph

# %%
#import libraries
import seaborn as sns
import pandas
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")

# %%
sns.barplot(x="class", y="fare",data=kashti,
           linewidth=3, facecolor=(.1,.3,.3,0.5),
           errcolor=".6", edgecolor=".2")
# Out:
# C:\Users\DELL\anaconda\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='class', ylabel='fare'>

# %%
<AxesSubplot:'class',ylabel='fare'>
